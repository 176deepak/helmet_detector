# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:01<00:00, 3.59MB/s]

# %%
model.train(data=r'E:\Projects\helmet_detector\config\config.yaml', epochs=1, save=True)
# Out:
# Ultralytics YOLOv8.0.146  Python-3.8.17 torch-2.0.1+cpu CPU (AMD Ryzen 7 3700U with Radeon Vega Mobile Gfx)
# ...
